# %%
import os, sys
from python_tools import *
# Out:
# python tools loaded.

# %%
# %matplotlib notebook

# %%
ALL = slice(None)

# %%
gst_df = pd.read_hdf("/Users/wketchum/Data/LDMX/base_generation_with_weights_02Mar21.hdf",key="gst_df")

# %%
gst_df
# Out:
#            iev  neu  fspl         tgt   Z   A  hitnuc  hitqrk  resid    sea  \
# 0            0   11    11  1000220480  22  48    2112       0      0  False
# 1            1   11    11  1000220480  22  48    2212       0    -99  False
# 2            2   11    11  1000220480  22  48    2112       0      0  False
# 3            3   11    11  1000220480  22  48    2212       0      6  False
# 4            4   11    11  1000220480  22  48    2212       0    -99  False
# ...        ...  ...   ...         ...  ..  ..     ...     ...    ...    ...
# 999995  999995   11    11  1000220480  22  48    2212       0    -99  False
# 999996  999996   11    11  1000220480  22  48    2212       0    -99  False
# 999997  999997   11    11  1000220480  22  48    2212       0    -99  False
# 999998  999998   11    11  1000220480  22  48    2212       0    -99  False
# 999999  999999   11    11  1000220480  22  48    2212       0    -99  False
#
# ...

# %%
bins = np.arange(0,1.0,0.04)
var="ptl"
units="GeV/c"

query='index' #all
wght="MFP_pi"
sigma=1

#title="%s, $\\nu_\mu$ CC"%(fd_title)
xlabel="Final State Lepton $p_{T}$ (%s)"%(units)
ylabel="Events / %2.2f %s "%(bins[-1]-bins[-2],units)

df=gst_df.query(query)

fig,ax = plt.subplots()

plt.grid(axis='y', linewidth=0.5)
plt.hist(df[var], weights=df["wght"], color='red', label="CV", bins=bins,**pltops_hist)
plt.hist(df[var], weights=df["wght_%s_p%d"%(wght,sigma)], 
         color='blue', 
         label="%s +%d$\sigma$"%(wght,sigma), bins=bins,**pltops_hist)
plt.hist(df[var], weights=df["wght_%s_n%d"%(wght,sigma)], 
         color='green', 
         label="%s -%d$\sigma$"%(wght,sigma), bins=bins,**pltops_hist)
plt.legend()

#plt.title(title)
plt.xlabel(xlabel)
plt.ylabel(ylabel)

plt.show()
#plt.savefig("/Users/wketchum/Downloads/numucc_e_%s.png"%fd_leg)
# Out:
# <img src="data:image/png;base64,..." width="1280">

# %%
bins = np.arange(0,1.0,0.04)
var="ptl"
units="GeV/c"

query='index' #all
wght="MFP_N"
sigma=1

#title="%s, $\\nu_\mu$ CC"%(fd_title)
xlabel="Final State Lepton $p_{T}$ (%s)"%(units)
ylabel="Events / %2.2f %s "%(bins[-1]-bins[-2],units)

df=gst_df.query(query)

fig,ax = plt.subplots()

plt.grid(axis='y', linewidth=0.5)
plt.hist(df[var], weights=df["wght"], color='red', label="CV", bins=bins,**pltops_hist)
plt.hist(df[var], weights=df["wght_%s_p%d"%(wght,sigma)], 
         color='blue', 
         label="%s +%d$\sigma$"%(wght,sigma), bins=bins,**pltops_hist)
plt.hist(df[var], weights=df["wght_%s_n%d"%(wght,sigma)], 
         color='green', 
         label="%s -%d$\sigma$"%(wght,sigma), bins=bins,**pltops_hist)
plt.legend()

#plt.title(title)
plt.xlabel(xlabel)
plt.ylabel(ylabel)

plt.show()
#plt.savefig("/Users/wketchum/Downloads/numucc_e_%s.png"%fd_leg)
# Out:
# <img src="data:image/png;base64,..." width="1280">

# %%
bins = np.arange(0.0,1.,0.1)
var="ke_n1"
units="GeV"

query='ptl>0.4'
wght="MFP_pi"
sigma=1

title="Leading Neutron Kinetic Energy\n(Trigger and Acceptance Applied)"
xlabel="Kinetic Energy (%s)"%(units)
ylabel="Events / %2.2f %s "%(bins[-1]-bins[-2],units)

df=gst_df.query(query)

fig,ax = plt.subplots()

plt.grid(axis='y', linewidth=0.5)
plt.hist(df[var], weights=df["wght"], color='red', label="CV", bins=bins,**pltops_hist)
plt.hist(df[var], weights=df["wght_%s_p%d"%(wght,sigma)], 
         color='blue', 
         label="%s +%d$\sigma$"%(wght,sigma), bins=bins,**pltops_hist)
plt.hist(df[var], weights=df["wght_%s_n%d"%(wght,sigma)], 
         color='green', 
         label="%s -%d$\sigma$"%(wght,sigma), bins=bins,**pltops_hist)
plt.legend()

#plt.title(title)
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.yscale("log")

plt.show()
#plt.savefig("/Users/wketchum/Downloads/numucc_e_%s.png"%fd_leg)
# Out:
# <img src="data:image/png;base64,..." width="1280">
